# %%
# !git clone https://github.com/volkamerlab/teachopencadd.git
# Out:
# Cloning into 'teachopencadd'...
# remote: Enumerating objects: 17115, done.
# remote: Counting objects: 100% (2093/2093), done.
# remote: Compressing objects: 100% (969/969), done.
# remote: Total 17115 (delta 1309), reused 1786 (delta 1122), pack-reused 15022
# Receiving objects: 100% (17115/17115), 849.77 MiB | 33.24 MiB/s, done.
# Resolving deltas: 100% (11506/11506), done.
# Updating files: 100% (468/468), done.

# %% [markdown]
# # **Theory**
# Introduction to clustering and Jarvis-Patrick algorithm
# Clustering can be defined as the task of grouping a set of objects in such a way that objects in the same group (called a cluster) are more similar (in some sense) to each other than to those in other groups (clusters).
#
# Compound clustering in pharmaceutical research is often based on chemical or structural similarity between compounds to find groups that share properties as well as to design a diverse and representative set for further analysis.
#
# **General procedure:**
#
# Methods are based on clustering data by similarity between neighboring points.
# In cheminformatics, compounds are often encoded as molecular fingerprints and similarity can be described by the Tanimoto similarity (see Talktorial T004).
# Quick reminder:
#
# Fingerprints are binary vectors where each bit indicates the presence or absence of a particular substructural fragment within a molecule.
# Similarity (or distance) matrix: The similarity between each pair of molecules represented by binary fingerprints is most frequently quantified using the Tanimoto coefficient, which measures the number of common features (bits).
# The value of the Tanimoto coefficient ranges from zero (no similarity) to one (high similarity).
# There are a number of clustering algorithms available, with the Jarvis-Patrick clustering being one of the most widely used algorithms in the pharmaceutical context.
#
# Jarvis-Patrick clustering algorithm is defined by two parameters
#  and
# :
#
# Calculate the set of
#  nearest neighbors for each molecule.
# Two molecules cluster together if
# they are in each others list of nearest neighbors
# they have at least
#  of their
#  nearest neighbors in common.
# The Jarvis-Patrick clustering algorithm is deterministic and able to deal with large sets of molecules in a matter of a few hours. However, a downside lies in the fact that this method tends to produce large heterogeneous clusters (see Butina clustering, referenced above).
#
# More clustering algorithms can also be found in the scikit-learn clustering module.
#
# # **Detailed explanation of Butina clustering**
# Butina clustering (J. Chem. Inf. Model. (1999), 39 (4), 747) was developed to identify smaller but homogeneous clusters, with the prerequisite that (at least) the cluster centroid will be more similar than a given threshold to every other molecule in the cluster.
#
# These are the key steps in this clustering approach (see flowchart below):
#
# 1. Data preparation and compound encoding
# To identify chemical similarities, the compounds in the input data (e.g. given as SMILES) will be encoded as molecular fingerprints, e.g., RDK5 fingerprint which is a subgraph-based fingerprint similar to the well known Daylight Fingerprint (which was used in the original publication).
# 2. Tanimoto similarity (or distance) matrix
# The similarity between two fingerprints is calculated using the Tanimoto coefficient.
# Matrix with Tanimoto similarities between all possible molecule/fingerprint pairs (
#  similarity matrix with
# =number of molecules, upper triangle matrix used only).
# Equally, the distances matrix can be calculated (
# ).
# 3. Clustering molecules: Centroids and exclusion spheres
# Note: Molecules will be clustered together, if they have a maximum distance below a specified cut-off from the cluster centroid (if distance matrix is used) or if they have a minimum similarity above the specified cut-off (if similarity matrix is used).
#
# **Identification of potential cluster centroids**
#
# The cluster centroid is the molecule within a given cluster which has the largest number of neighbors.
# # **Annotate neighbors:**
# For each molecule count all molecules with a Tanimoto distance below a given threshold.
# Sort the molecules by their number of neighbors in descending order, so that potential cluster centroids (i.e. the compounds with the largest number of neighbors) are placed at the top of the file.
# Clustering based on the exclusion spheres
#
# Starting with the first molecule (centroid) in the sorted list.
# All molecules with a Tanimoto index above or equal to the cut-off value used for clustering then become members of that cluster (in case of similarity).
# Each molecule that has been identified as a member of the given cluster is flagged and removed from further comparisons. Thus, flagged molecules cannot become either another cluster centroid or a member of another cluster. This process is like putting an exclusion sphere around the newly formed cluster.
# Once the first compound in the list has found all its neighbors, the first available (i.e. not flagged) compound at the top of the list becomes the new cluster centroid.
# The same process is repeated for all other unflagged molecules down the list.
# Molecules that have not been flagged by the end of the clustering process become singletons.
# Note that some molecules assigned as singletons can have neighbors at the given Tanimoto similarity index, but those neighbors have been excluded by a stronger cluster centroid.

# %% [markdown]
# # **Clustering with the Butina algorithm**

# %%
# !pip install rdkit
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rdkit
#   Downloading rdkit-2023.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.7/29.7 MB 57.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit) (1.22.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (8.4.0)
# Installing collected packages: rdkit
# Successfully installed rdkit-2023.3.1

# %%
cd ..
# Out:
# /content

# %%
# !python setup.py install
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.10/dist-packages/setuptools/command/build_py.py:201: _Warning: Package 'teachopencadd.talktorials.T005_compound_clustering.data' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'teachopencadd.talktorials.T005_compound_clustering.data' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'teachopencadd.talktorials.T005_compound_clustering.data' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'teachopencadd.talktorials.T005_compound_clustering.data' to be distributed and are
#         already explicitly excluding 'teachopencadd.talktorials.T005_compound_clustering.data' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.10/dist-packages/setuptools/command/build_py.py:201: _Warning: Package 'teachopencadd.talktorials.T005_compound_clustering.images' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'teachopencadd.talktorials.T005_compound_clustering.images' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'teachopencadd.talktorials.T005_compound_clustering.images' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'teachopencadd.talktorials.T005_compound_clustering.images' to be distributed and are
#         already explicitly excluding 'teachopencadd.talktorials.T005_compound_clustering.images' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.10/dist-packages/setuptools/command/build_py.py:201: _Warning: Package 'teachopencadd.talktorials.T006_compound_maximum_common_substructures' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'teachopencadd.talktorials.T006_compound_maximum_common_substructures' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'teachopencadd.talktorials.T006_compound_maximum_common_substructures' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'teachopencadd.talktorials.T006_compound_maximum_common_substructures' to be distributed and are
#         already explicitly excluding 'teachopencadd.talktorials.T006_compound_maximum_common_substructures' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.10/dist-packages/setuptools/command/build_py.py:201: _Warning: Package 'teachopencadd.talktorials.T006_compound_maximum_common_substructures.data' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'teachopencadd.talktorials.T006_compound_maximum_common_substructures.data' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'teachopencadd.talktorials.T006_compound_maximum_common_substructures.data' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'teachopencadd.talktorials.T006_compound_maximum_common_substructures.data' to be distributed and are
#         already explicitly excluding 'teachopencadd.talktorials.T006_compound_maximum_common_substructures.data' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.10/dist-packages/setuptools/command/build_py.py:201: _Warning: Package 'teachopencadd.talktorials.T006_compound_maximum_common_substructures.images' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'teachopencadd.talktorials.T006_compound_maximum_common_substructures.images' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'teachopencadd.talktorials.T006_compound_maximum_common_substructures.images' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'teachopencadd.talktorials.T006_compound_maximum_common_substructures.images' to be distributed and are
#         already explicitly excluding 'teachopencadd.talktorials.T006_compound_maximum_common_substructures.images' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.10/dist-packages/setuptools/command/build_py.py:201: _Warning: Package 'teachopencadd.talktorials.T007_compound_activity_machine_learning' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'teachopencadd.talktorials.T007_compound_activity_machine_learning' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'teachopencadd.talktorials.T007_compound_activity_machine_learning' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'teachopencadd.talktorials.T007_compound_activity_machine_learning' to be distributed and are
#         already explicitly excluding 'teachopencadd.talktorials.T007_compound_activity_machine_learning' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.10/dist-packages/setuptools/command/build_py.py:201: _Warning: Package 'teachopencadd.talktorials.T007_compound_activity_machine_learning.data' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'teachopencadd.talktorials.T007_compound_activity_machine_learning.data' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'teachopencadd.talktorials.T007_compound_activity_machine_learning.data' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'teachopencadd.talktorials.T007_compound_activity_machine_learning.data' to be distributed and are
#         already explicitly excluding 'teachopencadd.talktorials.T007_compound_activity_machine_learning.data' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.10/dist-packages/setuptools/command/build_py.py:201: _Warning: Package 'teachopencadd.talktorials.T007_compound_activity_machine_learning.images' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'teachopencadd.talktorials.T007_compound_activity_machine_learning.images' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'teachopencadd.talktorials.T007_compound_activity_machine_learning.images' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'teachopencadd.talktorials.T007_compound_activity_machine_learning.images' to be distributed and are
#         already explicitly excluding 'teachopencadd.talktorials.T007_compound_activity_machine_learning.images' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.10/dist-packages/setuptools/command/build_py.py:201: _Warning: Package 'teachopencadd.talktorials.T008_query_pdb' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'teachopencadd.talktorials.T008_query_pdb' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'teachopencadd.talktorials.T008_query_pdb' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'teachopencadd.talktorials.T008_query_pdb' to be distributed and are
#         already explicitly excluding 'teachopencadd.talktorials.T008_query_pdb' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.10/dist-packages/setuptools/command/build_py.py:201: _Warning: Package 'teachopencadd.talktorials.T008_query_pdb.data' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'teachopencadd.talktorials.T008_query_pdb.data' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'teachopencadd.talktorials.T008_query_pdb.data' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'teachopencadd.talktorials.T008_query_pdb.data' to be distributed and are
#         already explicitly excluding 'teachopencadd.talktorials.T008_query_pdb.data' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.10/dist-packages/setuptools/command/build_py.py:201: _Warning: Package 'teachopencadd.talktorials.T008_query_pdb.images' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'teachopencadd.talktorials.T008_query_pdb.images' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'teachopencadd.talktorials.T008_query_pdb.images' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'teachopencadd.talktorials.T008_query_pdb.images' to be distributed and are
#         already explicitly excluding 'teachopencadd.talktorials.T008_query_pdb.images' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.10/dist-packages/setuptools/command/build_py.py:201: _Warning: Package 'teachopencadd.talktorials.T009_compound_ensemble_pharmacophores' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'teachopencadd.talktorials.T009_compound_ensemble_pharmacophores' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'teachopencadd.talktorials.T009_compound_ensemble_pharmacophores' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'teachopencadd.talktorials.T009_compound_ensemble_pharmacophores' to be distributed and are
#         already explicitly excluding 'teachopencadd.talktorials.T009_compound_ensemble_pharmacophores' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.10/dist-packages/setuptools/command/build_py.py:201: _Warning: Package 'teachopencadd.talktorials.T009_compound_ensemble_pharmacophores.data' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'teachopencadd.talktorials.T009_compound_ensemble_pharmacophores.data' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'teachopencadd.talktorials.T009_compound_ensemble_pharmacophores.data' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'teachopencadd.talktorials.T009_compound_ensemble_pharmacophores.data' to be distributed and are
#         already explicitly excluding 'teachopencadd.talktorials.T009_compound_ensemble_pharmacophores.data' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.10/dist-packages/setuptools/command/build_py.py:201: _Warning: Package 'teachopencadd.talktorials.T009_compound_ensemble_pharmacophores.images' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'teachopencadd.talktorials.T009_compound_ensemble_pharmacophores.images' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'teachopencadd.talktorials.T009_compound_ensemble_pharmacophores.images' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'teachopencadd.talktorials.T009_compound_ensemble_pharmacophores.images' to be distributed and are
#         already explicitly excluding 'teachopencadd.talktorials.T009_compound_ensemble_pharmacophores.images' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.10/dist-packages/setuptools/command/build_py.py:201: _Warning: Package 'teachopencadd.talktorials.T010_binding_site_comparison' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'teachopencadd.talktorials.T010_binding_site_comparison' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'teachopencadd.talktorials.T010_binding_site_comparison' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'teachopencadd.talktorials.T010_binding_site_comparison' to be distributed and are
#         already explicitly excluding 'teachopencadd.talktorials.T010_binding_site_comparison' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.10/dist-packages/setuptools/command/build_py.py:201: _Warning: Package 'teachopencadd.talktorials.T010_binding_site_comparison.data' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'teachopencadd.talktorials.T010_binding_site_comparison.data' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'teachopencadd.talktorials.T010_binding_site_comparison.data' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'teachopencadd.talktorials.T010_binding_site_comparison.data' to be distributed and are
#         already explicitly excluding 'teachopencadd.talktorials.T010_binding_site_comparison.data' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.10/dist-packages/setuptools/command/build_py.py:201: _Warning: Package 'teachopencadd.talktorials.T010_binding_site_comparison.images' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'teachopencadd.talktorials.T010_binding_site_comparison.images' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'teachopencadd.talktorials.T010_binding_site_comparison.images' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'teachopencadd.talktorials.T010_binding_site_comparison.images' to be distributed and are
#         already explicitly excluding 'teachopencadd.talktorials.T010_binding_site_comparison.images' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.10/dist-packages/setuptools/command/build_py.py:201: _Warning: Package 'teachopencadd.talktorials.T011_query_online_api_webservices' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'teachopencadd.talktorials.T011_query_online_api_webservices' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'teachopencadd.talktorials.T011_query_online_api_webservices' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'teachopencadd.talktorials.T011_query_online_api_webservices' to be distributed and are
#         already explicitly excluding 'teachopencadd.talktorials.T011_query_online_api_webservices' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.10/dist-packages/setuptools/command/build_py.py:201: _Warning: Package 'teachopencadd.talktorials.T011_query_online_api_webservices.data' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'teachopencadd.talktorials.T011_query_online_api_webservices.data' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'teachopencadd.talktorials.T011_query_online_api_webservices.data' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'teachopencadd.talktorials.T011_query_online_api_webservices.data' to be distributed and are
#         already explicitly excluding 'teachopencadd.talktorials.T011_query_online_api_webservices.data' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.10/dist-packages/setuptools/command/build_py.py:201: _Warning: Package 'teachopencadd.talktorials.T011_query_online_api_webservices.images' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'teachopencadd.talktorials.T011_query_online_api_webservices.images' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'teachopencadd.talktorials.T011_query_online_api_webservices.images' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'teachopencadd.talktorials.T011_query_online_api_webservices.images' to be distributed and are
#         already explicitly excluding 'teachopencadd.talktorials.T011_query_online_api_webservices.images' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.10/dist-packages/setuptools/command/build_py.py:201: _Warning: Package 'teachopencadd.talktorials.T012_query_klifs' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'teachopencadd.talktorials.T012_query_klifs' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'teachopencadd.talktorials.T012_query_klifs' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'teachopencadd.talktorials.T012_query_klifs' to be distributed and are
#         already explicitly excluding 'teachopencadd.talktorials.T012_query_klifs' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# ...
# copying build/lib/teachopencadd/talktorials/T019_md_simulation/images/3poz_assembly-1.jpeg -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T019_md_simulation/images
# copying build/lib/teachopencadd/talktorials/T019_md_simulation/images/MD_water.gif -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T019_md_simulation/images
# copying build/lib/teachopencadd/talktorials/T019_md_simulation/README.md -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T019_md_simulation
# creating build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T019_md_simulation/data
# copying build/lib/teachopencadd/talktorials/T019_md_simulation/data/README.md -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T019_md_simulation/data
# copying build/lib/teachopencadd/talktorials/T019_md_simulation/talktorial.ipynb -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T019_md_simulation
# creating build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T025_kinase_similarity_kissim
# creating build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T025_kinase_similarity_kissim/images
# copying build/lib/teachopencadd/talktorials/T025_kinase_similarity_kissim/images/README.md -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T025_kinase_similarity_kissim/images
# copying build/lib/teachopencadd/talktorials/T025_kinase_similarity_kissim/README.md -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T025_kinase_similarity_kissim
# creating build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T025_kinase_similarity_kissim/data
# copying build/lib/teachopencadd/talktorials/T025_kinase_similarity_kissim/data/README.md -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T025_kinase_similarity_kissim/data
# copying build/lib/teachopencadd/talktorials/T025_kinase_similarity_kissim/data/kinase_distance_matrix.csv -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T025_kinase_similarity_kissim/data
# copying build/lib/teachopencadd/talktorials/T025_kinase_similarity_kissim/data/kissim_fingerprints.csv -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T025_kinase_similarity_kissim/data
# copying build/lib/teachopencadd/talktorials/T025_kinase_similarity_kissim/data/frozen_structure_klifs_ids.csv -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T025_kinase_similarity_kissim/data
# copying build/lib/teachopencadd/talktorials/T025_kinase_similarity_kissim/talktorial.ipynb -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T025_kinase_similarity_kissim
# creating build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T013_query_pubchem
# creating build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T013_query_pubchem/images
# copying build/lib/teachopencadd/talktorials/T013_query_pubchem/images/README.md -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T013_query_pubchem/images
# copying build/lib/teachopencadd/talktorials/T013_query_pubchem/README.md -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T013_query_pubchem
# creating build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T013_query_pubchem/data
# copying build/lib/teachopencadd/talktorials/T013_query_pubchem/data/similar_smiles.txt -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T013_query_pubchem/data
# copying build/lib/teachopencadd/talktorials/T013_query_pubchem/data/README.md -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T013_query_pubchem/data
# copying build/lib/teachopencadd/talktorials/T013_query_pubchem/data/complex.pdb -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T013_query_pubchem/data
# copying build/lib/teachopencadd/talktorials/T013_query_pubchem/data/data_filtered.csv -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T013_query_pubchem/data
# copying build/lib/teachopencadd/talktorials/T013_query_pubchem/data/data_raw.csv -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T013_query_pubchem/data
# copying build/lib/teachopencadd/talktorials/T013_query_pubchem/data/protein.mol2 -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T013_query_pubchem/data
# copying build/lib/teachopencadd/talktorials/T013_query_pubchem/talktorial.ipynb -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T013_query_pubchem
# creating build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T027_kinase_similarity_ligand_profile
# creating build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T027_kinase_similarity_ligand_profile/images
# copying build/lib/teachopencadd/talktorials/T027_kinase_similarity_ligand_profile/images/kinmap_n_activities_per_kinase.png -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T027_kinase_similarity_ligand_profile/images
# copying build/lib/teachopencadd/talktorials/T027_kinase_similarity_ligand_profile/images/README.md -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T027_kinase_similarity_ligand_profile/images
# copying build/lib/teachopencadd/talktorials/T027_kinase_similarity_ligand_profile/README.md -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T027_kinase_similarity_ligand_profile
# creating build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T027_kinase_similarity_ligand_profile/data
# copying build/lib/teachopencadd/talktorials/T027_kinase_similarity_ligand_profile/data/kinase_similarity_matrix.csv -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T027_kinase_similarity_ligand_profile/data
# copying build/lib/teachopencadd/talktorials/T027_kinase_similarity_ligand_profile/data/README.md -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T027_kinase_similarity_ligand_profile/data
# copying build/lib/teachopencadd/talktorials/T027_kinase_similarity_ligand_profile/data/kinase_distance_matrix.csv -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T027_kinase_similarity_ligand_profile/data
# copying build/lib/teachopencadd/talktorials/T027_kinase_similarity_ligand_profile/talktorial.ipynb -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T027_kinase_similarity_ligand_profile
# creating build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T002_compound_adme
# creating build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T002_compound_adme/images
# copying build/lib/teachopencadd/talktorials/T002_compound_adme/images/adme.png -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T002_compound_adme/images
# copying build/lib/teachopencadd/talktorials/T002_compound_adme/images/README.md -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T002_compound_adme/images
# copying build/lib/teachopencadd/talktorials/T002_compound_adme/images/radarplot.png -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T002_compound_adme/images
# copying build/lib/teachopencadd/talktorials/T002_compound_adme/README.md -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T002_compound_adme
# creating build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T002_compound_adme/data
# copying build/lib/teachopencadd/talktorials/T002_compound_adme/data/README.md -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T002_compound_adme/data
# copying build/lib/teachopencadd/talktorials/T002_compound_adme/data/EGFR_compounds_lipinski.csv -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T002_compound_adme/data
# copying build/lib/teachopencadd/talktorials/T002_compound_adme/talktorial.ipynb -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T002_compound_adme
# creating build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction
# creating build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction/utils
# copying build/lib/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction/utils/__init__.py -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction/utils
# copying build/lib/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction/utils/kiba_analysis.py -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction/utils
# creating build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction/images
# copying build/lib/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction/images/prot_graph_creation.png -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction/images
# copying build/lib/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction/images/calphas.jpg -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction/images
# copying build/lib/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction/images/basic_structure.png -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction/images
# copying build/lib/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction/images/train_perf.png -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction/images
# copying build/lib/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction/README.md -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction
# creating build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction/data
# copying build/lib/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction/data/KIBA.csv -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction/data
# copying build/lib/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction/data/tmp.txt -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction/data
# copying build/lib/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction/data/final_model.pth -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction/data
# copying build/lib/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction/talktorial.ipynb -> build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction
# copying build/lib/teachopencadd/utils.py -> build/bdist.linux-x86_64/egg/teachopencadd
# creating build/bdist.linux-x86_64/egg/teachopencadd/tests
# copying build/lib/teachopencadd/tests/test_cli.py -> build/bdist.linux-x86_64/egg/teachopencadd/tests
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/_version.py to _version.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/cli.py to cli.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T018_automated_cadd_pipeline/utils/ligand_similarity_search.py to ligand_similarity_search.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T018_automated_cadd_pipeline/utils/interaction_analysis.py to interaction_analysis.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T018_automated_cadd_pipeline/utils/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T018_automated_cadd_pipeline/utils/consts.py to consts.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T018_automated_cadd_pipeline/utils/ligand.py to ligand.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T018_automated_cadd_pipeline/utils/frozen_data.py to frozen_data.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T018_automated_cadd_pipeline/utils/optimized_ligands.py to optimized_ligands.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T018_automated_cadd_pipeline/utils/specs.py to specs.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T018_automated_cadd_pipeline/utils/protein.py to protein.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T018_automated_cadd_pipeline/utils/helpers/nglview.py to nglview.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T018_automated_cadd_pipeline/utils/helpers/pdb.py to pdb.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T018_automated_cadd_pipeline/utils/helpers/io.py to io.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T018_automated_cadd_pipeline/utils/helpers/dogsitescorer.py to dogsitescorer.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T018_automated_cadd_pipeline/utils/helpers/plip.py to plip.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T018_automated_cadd_pipeline/utils/helpers/smina.py to smina.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T018_automated_cadd_pipeline/utils/helpers/pubchem.py to pubchem.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T018_automated_cadd_pipeline/utils/helpers/obabel.py to obabel.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T018_automated_cadd_pipeline/utils/helpers/rdkit.py to rdkit.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T018_automated_cadd_pipeline/utils/docking.py to docking.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T018_automated_cadd_pipeline/utils/binding_site_detection.py to binding_site_detection.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T018_automated_cadd_pipeline/utils/lead_optimization_pipeline.py to lead_optimization_pipeline.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction/utils/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/talktorials/T038_protein_ligand_interaction_prediction/utils/kiba_analysis.py to kiba_analysis.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/utils.py to utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/teachopencadd/tests/test_cli.py to test_cli.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying teachopencadd.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying teachopencadd.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying teachopencadd.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying teachopencadd.egg-info/entry_points.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying teachopencadd.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# teachopencadd.__pycache__.cli.cpython-310: module references __file__
# teachopencadd.talktorials.T018_automated_cadd_pipeline.utils.__pycache__.frozen_data.cpython-310: module references __file__
# creating dist
# creating 'dist/teachopencadd-2023.5.2-py3.10.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing teachopencadd-2023.5.2-py3.10.egg
# creating /usr/local/lib/python3.10/dist-packages/teachopencadd-2023.5.2-py3.10.egg
# Extracting teachopencadd-2023.5.2-py3.10.egg to /usr/local/lib/python3.10/dist-packages
# Adding teachopencadd 2023.5.2 to easy-install.pth file
# Installing teachopencadd script to /usr/local/bin
#
# Installed /usr/local/lib/python3.10/dist-packages/teachopencadd-2023.5.2-py3.10.egg
# Processing dependencies for teachopencadd==2023.5.2
# Finished processing dependencies for teachopencadd==2023.5.2

# %%
#Load data and calculate fingerprints
import time
import random
from pathlib import Path

import pandas as pd
import numpy
import matplotlib.pyplot as plt
from rdkit import Chem
from rdkit import DataStructs
from rdkit.ML.Cluster import Butina
from rdkit.Chem import Draw
from rdkit.Chem import rdFingerprintGenerator

from teachopencadd.build.lib.teachopencadd.utils import seed_everything

seed_everything()  # fix seed to get deterministic outputs

# %%
ls
# Out:
# build/     docs/        __pycache__/  setup.py                 versioneer.py
# devtools/  LICENSE      README.md     teachopencadd/
# dist/      MANIFEST.in  setup.cfg     teachopencadd.egg-info/

# %%
HERE = Path(_dh[-1])
DATA = HERE / "data"

# %%
# Load and have a look into data
# Filtered data taken from **Talktorial T002**
compound_df = pd.read_csv(
    HERE / "/content/teachopencadd/teachopencadd/talktorials/T002_compound_adme/data/EGFR_compounds_lipinski.csv",
    index_col=0,
)
print("Dataframe shape:", compound_df.shape)
compound_df.head()
# Out:
# Dataframe shape: (4635, 10)
#   molecule_chembl_id   IC50 units                               smiles  \
# 0        CHEMBL63786  0.003    nM    Brc1cccc(Nc2ncnc3cc4ccccc4cc23)c1
# 1        CHEMBL35820  0.006    nM  CCOc1cc2ncnc(Nc3cccc(Br)c3)c2cc1OCC
# 2        CHEMBL53711  0.006    nM   CN(C)c1cc2c(Nc3cccc(Br)c3)ncnc2cn1
# 3        CHEMBL66031  0.008    nM  Brc1cccc(Nc2ncnc3cc4[nH]cnc4cc23)c1
# 4        CHEMBL53753  0.008    nM      CNc1cc2c(Nc3cccc(Br)c3)ncnc2cn1
#
#        pIC50  molecular_weight  n_hba  n_hbd    logp  ro5_fulfilled
# 0  11.522879        349.021459      3      1  5.2891           True
# 1  11.221849        387.058239      5      1  4.9333           True
# 2  11.221849        343.043258      5      1  3.5969           True
# 3  11.096910        339.011957      4      2  4.0122           True
# 4  11.096910        329.027607      5      2  3.5726           True

# %%
# Create molecules from SMILES and store in array
compounds = []
# .itertuples() returns a (index, column1, column2, ...) tuple per row
# we don't need index so we use _ instead
# note how we are slicing the dataframe to only the two columns we need now
for _, chembl_id, smiles in compound_df[["molecule_chembl_id", "smiles"]].itertuples():
    compounds.append((Chem.MolFromSmiles(smiles), chembl_id))
compounds[:5]
# Out:
# [(<rdkit.Chem.rdchem.Mol at 0x7f62352ad310>, 'CHEMBL63786'),
#  (<rdkit.Chem.rdchem.Mol at 0x7f62352ad150>, 'CHEMBL35820'),
#  (<rdkit.Chem.rdchem.Mol at 0x7f62352ad1c0>, 'CHEMBL53711'),
#  (<rdkit.Chem.rdchem.Mol at 0x7f62352ad0e0>, 'CHEMBL66031'),
#  (<rdkit.Chem.rdchem.Mol at 0x7f62352ac4a0>, 'CHEMBL53753')]

# %%
# Create fingerprints for all molecules
rdkit_gen = rdFingerprintGenerator.GetRDKitFPGenerator(maxPath=5)
fingerprints = [rdkit_gen.GetFingerprint(mol) for mol, idx in compounds]

# How many compounds/fingerprints do we have?
print("Number of compounds converted:", len(fingerprints))
print("Fingerprint length per compound:", len(fingerprints[0]))
# NBVAL_CHECK_OUTPUT
# Out:
# Number of compounds converted: 4635
# Fingerprint length per compound: 2048

# %% [markdown]
# **Tanimoto similarity and distance matrix**
#
# Now that we generated fingerprints, we move on to the next step: The identification of potential cluster centroids. For this, we define functions to calculate the Tanimoto similarity and distance matrix.

# %%
def tanimoto_distance_matrix(fp_list):
    """Calculate distance matrix for fingerprint list"""
    dissimilarity_matrix = []
    # Notice how we are deliberately skipping the first and last items in the list
    # because we don't need to compare them against themselves
    for i in range(1, len(fp_list)):
        # Compare the current fingerprint against all the previous ones in the list
        similarities = DataStructs.BulkTanimotoSimilarity(fp_list[i], fp_list[:i])
        # Since we need a distance matrix, calculate 1-x for every element in similarity matrix
        dissimilarity_matrix.extend([1 - x for x in similarities])
    return dissimilarity_matrix

# %%
# Example: Calculate single similarity of two fingerprints
# NBVAL_CHECK_OUTPUT
sim = DataStructs.TanimotoSimilarity(fingerprints[0], fingerprints[1])
print(f"Tanimoto similarity: {sim:.2f}, distance: {1-sim:.2f}")
# Out:
# Tanimoto similarity: 0.73, distance: 0.27

# %%
# Example: Calculate distance matrix (distance = 1-similarity)
tanimoto_distance_matrix(fingerprints)[0:5]
# Out:
# [0.26996197718631176,
#  0.26538461538461533,
#  0.40866873065015474,
#  0.09345794392523366,
#  0.31182795698924726]

# %%
# Side note: That looked like a list and not a matrix.
# But it is a triangular similarity matrix in the form of a list
n = len(fingerprints)

# Calculate number of elements in triangular matrix via n*(n-1)/2
elem_triangular_matr = (n * (n - 1)) / 2
print(
    f"Elements in the triangular matrix ({elem_triangular_matr:.0f}) ==",
    f"tanimoto_distance_matrix(fingerprints) ({len(tanimoto_distance_matrix(fingerprints))})",
)
# NBVAL_CHECK_OUTPUT
# Out:
# Elements in the triangular matrix (10739295) == tanimoto_distance_matrix(fingerprints) (10739295)

# %% [markdown]
# # **Clustering molecules:**
# Centroids and exclusion spheres
# In this part, we cluster the molecules and look at the results.
#
# Define a clustering function.

# %%
def cluster_fingerprints(fingerprints, cutoff=0.2):
    """Cluster fingerprints
    Parameters:
        fingerprints
        cutoff: threshold for the clustering
    """
    # Calculate Tanimoto distance matrix
    distance_matrix = tanimoto_distance_matrix(fingerprints)
    # Now cluster the data with the implemented Butina algorithm:
    clusters = Butina.ClusterData(distance_matrix, len(fingerprints), cutoff, isDistData=True)
    clusters = sorted(clusters, key=len, reverse=True)
    return clusters

# %% [markdown]
# Cluster the molecules based on their fingerprint similarity.

# %%
# Run the clustering procedure for the dataset
clusters = cluster_fingerprints(fingerprints, cutoff=0.3)

# Give a short report about the numbers of clusters and their sizes
num_clust_g1 = sum(1 for c in clusters if len(c) == 1)
num_clust_g5 = sum(1 for c in clusters if len(c) > 5)
num_clust_g25 = sum(1 for c in clusters if len(c) > 25)
num_clust_g100 = sum(1 for c in clusters if len(c) > 100)

print("total # clusters: ", len(clusters))
print("# clusters with only 1 compound: ", num_clust_g1)
print("# clusters with >5 compounds: ", num_clust_g5)
print("# clusters with >25 compounds: ", num_clust_g25)
print("# clusters with >100 compounds: ", num_clust_g100)
# NBVAL_CHECK_OUTPUT
# Out:
# total # clusters:  727
# # clusters with only 1 compound:  339
# # clusters with >5 compounds:  164
# # clusters with >25 compounds:  30
# # clusters with >100 compounds:  4

# %%
# Plot the size of the clusters
fig, ax = plt.subplots(figsize=(15, 4))
ax.set_xlabel("Cluster index")
ax.set_ylabel("Number of molecules")
ax.bar(range(1, len(clusters) + 1), [len(c) for c in clusters], lw=5);

# %%
#How to pick a reasonable cutoff?
#Since the clustering result depends on the threshold chosen by the user, we will have a closer look on the choice of a cutoff.
for cutoff in numpy.arange(0.0, 1.0, 0.2):
    clusters = cluster_fingerprints(fingerprints, cutoff=cutoff)
    fig, ax = plt.subplots(figsize=(15, 4))
    ax.set_title(f"Threshold: {cutoff:3.1f}")
    ax.set_xlabel("Cluster index")
    ax.set_ylabel("Number of molecules")
    ax.bar(range(1, len(clusters) + 1), [len(c) for c in clusters], lw=5)
    display(fig)

# %% [markdown]
# As you can see, the higher the threshold (distance cutoff), the more molecules are considered as similar and, therefore, clustered into less clusters. The lower the threshold, the more small clusters and "singletons" appear.
#
# The smaller the distance value cut-off, the more similar the compounds are required to be to belong to one cluster.
#
# Looking at the plots above, we decided to choose a distance threshold of 0.2. There are not many singletons and the cluster sizes don't have an extreme but smooth distribution.

# %%
cutoff = 0.2
clusters = cluster_fingerprints(fingerprints, cutoff=cutoff)

# Plot the size of the clusters - save plot
fig, ax = plt.subplots(figsize=(15, 4))
ax.set_xlabel("Cluster index")
ax.set_ylabel("# molecules")
ax.bar(range(1, len(clusters) + 1), [len(c) for c in clusters])
ax.set_title(f"Threshold: {cutoff:3.1f}")
fig.savefig(
    DATA / f"/content/teachopencadd/teachopencadd/talktorials/T005_compound_clustering/data/cluster_dist_cutoff_{cutoff:4.2f}.png",
    dpi=300,
    bbox_inches="tight",
    transparent=True,
)

print(
    f"Number of clusters: {len(clusters)} from {len(compounds)} molecules at distance cut-off {cutoff:.2f}"
)
print("Number of molecules in largest cluster:", len(clusters[0]))
print(
    f"Similarity between two random points in same cluster: {DataStructs.TanimotoSimilarity(fingerprints[clusters[0][0]], fingerprints[clusters[0][1]]):.2f}"
)
print(
    f"Similarity between two random points in different cluster: {DataStructs.TanimotoSimilarity(fingerprints[clusters[0][0]], fingerprints[clusters[1][0]]):.2f}"
)
# Out:
# Number of clusters: 1128 from 4635 molecules at distance cut-off 0.20
# Number of molecules in largest cluster: 145
# Similarity between two random points in same cluster: 0.82
# Similarity between two random points in different cluster: 0.22

# %% [markdown]
# # **Visualizing the clusters**
# 10 examples from largest cluster
# Now, let's have a closer look at the first 10 molecular structures of the first/largest clusters.

# %%
print("Ten molecules from largest cluster:")
# Draw molecules
Draw.MolsToGridImage(
    [compounds[i][0] for i in clusters[0][:10]],
    legends=[compounds[i][1] for i in clusters[0][:10]],
    molsPerRow=5,
)
# Out:
# Ten molecules from largest cluster:

# %% [markdown]
# 10 examples from second largest cluster

# %%
print("Ten molecules from second largest cluster:")
# Draw molecules
Draw.MolsToGridImage(
    [compounds[i][0] for i in clusters[1][:10]],
    legends=[compounds[i][1] for i in clusters[1][:10]],
    molsPerRow=5,
)
# Out:
# Ten molecules from second largest cluster:

# %% [markdown]
# The first ten molecules in the respective clusters look indeed similar to each other and many share a common scaffold (visually detected).
#
# See tutorial 6 for more information on how to calculate the maximum common substructure (MCS) of a set of molecules.
#
# **Examples from first 10 clusters**
# For comparison, we have a look at the cluster centers of the first 10 clusters.

# %%
print("Ten molecules from first 10 clusters:")
# Draw molecules
Draw.MolsToGridImage(
    [compounds[clusters[i][0]][0] for i in range(10)],
    legends=[compounds[clusters[i][0]][1] for i in range(10)],
    molsPerRow=5,
)
# Out:
# Ten molecules from first 10 clusters:

# %%
#Save cluster centers from first 3 clusters as SVG file.
# Generate image
img = Draw.MolsToGridImage(
    [compounds[clusters[i][0]][0] for i in range(0, 3)],
    legends=[f"Cluster {i}" for i in range(1, 4)],
    subImgSize=(200, 200),
    useSVG=True,
)

# Patch RAW svg data: convert non-transparent to transparent background and set font size
molsvg = img.data.replace("opacity:1.0", "opacity:0.0").replace("12px", "20px")

# Save altered SVG data to file
with open(DATA / "/content/teachopencadd/teachopencadd/talktorials/T005_compound_clustering/data/cluster_representatives.svg", "w") as f:
    f.write(molsvg)

# %% [markdown]
# While still some similarity is visible, clearly, the centroids from the different clusters look more dissimilar then the compounds within one cluster.
#
# Intra-cluster Tanimoto similarities
# We can also have a look at the intra-cluster Tanimoto similarities.

# %%
def intra_tanimoto(fps_clusters):
    """Function to compute Tanimoto similarity for all pairs of fingerprints in each cluster"""
    intra_similarity = []
    # Calculate intra similarity per cluster
    for cluster in fps_clusters:
        # Tanimoto distance matrix function converted to similarity matrix (1-distance)
        intra_similarity.append([1 - x for x in tanimoto_distance_matrix(cluster)])
    return intra_similarity

# %%
# Recompute fingerprints for 10 first clusters
mol_fps_per_cluster = []
for cluster in clusters[:10]:
    mol_fps_per_cluster.append([rdkit_gen.GetFingerprint(compounds[i][0]) for i in cluster])

# Compute intra-cluster similarity
intra_sim = intra_tanimoto(mol_fps_per_cluster)

# %%
# Violin plot with intra-cluster similarity

fig, ax = plt.subplots(figsize=(10, 5))
indices = list(range(10))
ax.set_xlabel("Cluster index")
ax.set_ylabel("Similarity")
ax.set_xticks(indices)
ax.set_xticklabels(indices)
ax.set_yticks(numpy.arange(0.6, 1.0, 0.1))
ax.set_title("Intra-cluster Tanimoto similarity", fontsize=13)
r = ax.violinplot(intra_sim, indices, showmeans=True, showmedians=True, showextrema=False)
r["cmeans"].set_color("red")
# mean=red, median=blue

# %% [markdown]
# **Picking the final list of compounds**
# In the following, we are going to pick a final list of max. 1000 compounds as a diverse subset.
#
# For this, we take the cluster centroid from each cluster (i.e. the first molecule of each cluster) and then for each cluster (starting with the largest one) we take the 10 molecules (or 50% if less than 10 molecules are left in the cluster) that are most similar to the centroid, until we have selected max. 1000 compounds. Thus, we have representatives of each cluster.
#
# Aim of this compound picking is to ensure the diversity for a smaller set of compounds which are proposed for testing in a confirmatory assay.
#
# Picking procedure was adapted from TDT tutorial notebook by S. Riniker and G. Landrum.
#
# As described there: the idea behind this approach is to ensure diversity (representatives of each cluster) while getting some SAR (structure-activity relationship) from the results of the confirmatory assay (groups of quite similar molecules from larger clusters retained).
#
# Get cluster centers.

# %%
# Get the cluster center of each cluster (first molecule in each cluster)
cluster_centers = [compounds[c[0]] for c in clusters]
# How many cluster centers/clusters do we have?
print("Number of cluster centers:", len(cluster_centers))
# NBVAL_CHECK_OUTPUT
# Out:
# Number of cluster centers: 1128

# %% [markdown]
# Sort clusters by size and molecules in each cluster by similarity.

# %%
# Sort the molecules within a cluster based on their similarity
# to the cluster center and sort the clusters based on their size
sorted_clusters = []
for cluster in clusters:
    if len(cluster) <= 1:
        continue  # Singletons
    # else:
    # Compute fingerprints for each cluster element
    sorted_fingerprints = [rdkit_gen.GetFingerprint(compounds[i][0]) for i in cluster]
    # Similarity of all cluster members to the cluster center
    similarities = DataStructs.BulkTanimotoSimilarity(
        sorted_fingerprints[0], sorted_fingerprints[1:]
    )
    # Add index of the molecule to its similarity (centroid excluded!)
    similarities = list(zip(similarities, cluster[1:]))
    # Sort in descending order by similarity
    similarities.sort(reverse=True)
    # Save cluster size and index of molecules in clusters_sort
    sorted_clusters.append((len(similarities), [i for _, i in similarities]))
    # Sort in descending order by cluster size
    sorted_clusters.sort(reverse=True)

# %%
# Count selected molecules, pick cluster centers first
selected_molecules = cluster_centers.copy()
# Take 10 molecules (or a maximum of 50%) of each cluster starting with the largest one
index = 0
pending = 1000 - len(selected_molecules)
while pending > 0 and index < len(sorted_clusters):
    # Take indices of sorted clusters
    tmp_cluster = sorted_clusters[index][1]
    # If the first cluster is > 10 big then take exactly 10 compounds
    if sorted_clusters[index][0] > 10:
        num_compounds = 10
    # If smaller, take half of the molecules
    else:
        num_compounds = int(0.5 * len(tmp_cluster)) + 1
    if num_compounds > pending:
        num_compounds = pending
    # Write picked molecules and their structures into list of lists called picked_fps
    selected_molecules += [compounds[i] for i in tmp_cluster[:num_compounds]]
    index += 1
    pending = 1000 - len(selected_molecules)
print("# Selected molecules:", len(selected_molecules))
# NBVAL_CHECK_OUTPUT
# Out:
# # Selected molecules: 1128

# %% [markdown]
# This set of diverse molecules could now be used for experimental testing.
#
# Bonus: analysis of run times
# At the end of the talktorial, we can play with the size of the dataset and see how the Butina clustering run time changes.

# %%
# Reuse old dataset
sampled_mols = compounds.copy()

# %% [markdown]
# Note that you can try out larger datasets, but data sizes larger than 10000 data points already start to consume quite some memory and time (that's why we stopped there).

# %%
# Helper function for time computation
def measure_runtime(sampled_mols):
    start_time = time.time()
    sampled_fingerprints = [rdkit_gen.GetFingerprint(m) for m, idx in sampled_mols]
    # Run the clustering with the dataset
    sampled_clusters = cluster_fingerprints(sampled_fingerprints, cutoff=0.3)
    return time.time() - start_time

# %%
len(sampled_mols)
# NBVAL_CHECK_OUTPUT
# Out:
# 4635

# %%
sample_sizes = [100, 500, 1000, 2000, 4000]
runtimes = []
# Take random samples with replacement
for size in sample_sizes:
    time_taken = measure_runtime(random.sample(sampled_mols, size))
    print(f"Dataset size {size}, time {time_taken:4.2f} seconds")
    runtimes.append(time_taken)
# Out:
# Dataset size 100, time 0.12 seconds
# Dataset size 500, time 0.41 seconds
# Dataset size 1000, time 0.80 seconds
# Dataset size 2000, time 1.73 seconds
# Dataset size 4000, time 5.00 seconds

# %%
fig, ax = plt.subplots()
ax.set_title("Runtime measurement of Butina Clustering with different dataset sizes")
ax.set_xlabel("# Molecules in data set")
ax.set_ylabel("Runtime in seconds")
ax.plot(sample_sizes, runtimes, "g^");

# %%
# Notice how the runtime is not exactly proportional to the sample size! It grows faster!

# Discussion
# We have introduced the Butina algorithm to cluster a compound dataset and discussed how to pick a reasonable clustering threshold. The clustering was rationalized by looking at example compounds from different clusters and by checking intra-cluster similarities. Finally, the clusters were used to pick a divers subset of compounds.
